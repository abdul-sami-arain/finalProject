# %% [markdown]
# #  FINAL PROJECT OF DATA SCIENCE COURSE BY JAWAN PAKISTAN

# %% [markdown]
# # ABDUL SAMI

# %% [markdown]
# ###### HEART DIESES DATASET FROM KAGGLE
# #### age:person's age
# #### sex:person's gender
# #### cp:chest pain of four types(1-4)
# #### trestbps:person's resting blood pressure
# #### chol:cholestrol level
# #### fbs:fasting blood suger
# #### restecg:(0-2)
# #### thalach:max heart rate achieved
# #### exang
# #### oldpeak
# #### slope
# #### ca
# #### thal(3:normal,6=fixed,7==reversable defect)
# #### target:0=no heart dieses , 1= heart dieses

# %%
#Here we are importing PYthon libraries for DataScience

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Here we are reading Our DataSet Through Python library Pandas as pd

data = pd.read_csv("HeartDiesesDataSet.csv")

# %%
"""now our whole data saved in variable name "data"
here we are using variable "data" to watch our whole DataSet"""

data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
"""this below code show us, how many patients have HeartDieases OR how many patients don't have HeartDieses 
(0=no HeartDieses,1=HeartDieses)"""

data["target"].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
#this below code show us, how many male AND female in our DataSet (0=Female,1=Male)

data["sex"].value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
"""Here we are using groupby Function which help us to find HeartDiese in Gender
(0=Female[0=no heart dieses, 1=heart dieses],1=Male[0=no heart dieses, 1=heart dieses])"""

data.groupby("sex")["target"].value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: target, dtype: int64

# %% [markdown]
# #### Here We have to show "age" content on the basis of "target" with plot

# %%
#Here we are using again groupby Function which help us to find HeartDieses OR not HeartDieses in Patients by "age" 

data.groupby("age")["target"].value_counts()
# Out:
# age  target
# 29   1          4
# 34   1          6
# 35   1          8
#      0          7
# 37   1          6
#                ..
# 70   1          3
# 71   1         11
# 74   1          3
# 76   1          3
# 77   0          3
# Name: target, Length: 75, dtype: int64

# %%
#Here we are using Python library matplotlib.pyplot as plt for plotting 

data.hist(figsize=(40,40))
plt.show()

# %% [markdown]
# #### Here We have to show "sex" content on the basis of "target" with plot

# %%
#Here we are using again groupby Function which help us to find HeartDieses OR not HeartDieses in Patients by "sex" 

data.groupby("sex")["target"].value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: target, dtype: int64

# %%
#Here we have changed all plot by Size

data.hist(figsize=(10,10))
plt.show()

# %%
#Here we have use seaborn as sns for plotting , here we have shown HeartDiese OR not HeartDieses in Male AND Female by plot 

sns.countplot(x="sex", hue="target", data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
"""this below code show us, how many patients have HeartDieases OR how many patients don't have HeartDieses 
(0=no HeartDieses,1=HeartDieses)"""


data["target"].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
#Here we have use seaborn as sns for plotting , here we have shown HeartDieses OR not HeartDieses Patients in Our DataSet by plot

sns.countplot(x="target",data=data)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %% [markdown]
# #### Here We have to show "age" content on the basis of "target" with plot

# %%
#Here we are using again groupby Function which help us to find HeartDieses OR not HeartDieses in Patients by "age" 

data.groupby("age")["target"].value_counts()
# Out:
# age  target
# 29   1          4
# 34   1          6
# 35   1          8
#      0          7
# 37   1          6
#                ..
# 70   1          3
# 71   1         11
# 74   1          3
# 76   1          3
# 77   0          3
# Name: target, Length: 75, dtype: int64

# %%
"""here we are using python two libraries 1.matplotlib.pyplot as plt 2.seaborn as sns.
using seaborn as sns for plot AND matplotlib.pyplot as plt for changing the plot Size
"""

plt.figure(figsize=(20,5))
sns.countplot(x="age",hue="target",data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# #### Here We have to show "fbs" content on the basis of "target" with plot

# %%
"""Here we are using again groupby Function which help us to find
Fasting Blood Suger(fbs) Problem OR not Fasting Blood Suger(fbs) Problem in Patients by "fbs" """ 

data.groupby("fbs")["target"].value_counts()
# Out:
# fbs  target
# 0    1         455
#      0         417
# 1    0          82
#      1          71
# Name: target, dtype: int64

# %%
"""Here we have use seaborn as sns for plotting , here we have shown Fasting Blood Suger(1=high)
OR not Fasting Blood Suger(0=Normal) in Male AND Female by plot """

sns.countplot(x="fbs", hue="target", data=data)
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='count'>

# %% [markdown]
# #### Here We have to show "chol" content on the basis of "target" with plot

# %%
"""Here we are using again groupby Function which help us to find
cholestrol(chol) Problem OR not cholestrol(chol) Problem in Patients by "chol" """ 

data.groupby("chol")["target"].value_counts()
# Out:
# chol  target
# 126   1         3
# 131   0         3
# 141   1         3
# 149   0         4
#       1         4
#                ..
# 394   1         3
# 407   0         4
# 409   0         3
# 417   1         3
# 564   1         3
# Name: target, Length: 201, dtype: int64

# %% [markdown]
# #### enumerate

# %%
"""Here we have use seaborn as sns for plotting , here we have shown cholestrol problem
OR not cholestrol problem in Male AND Female by plot """

sns.countplot(x="chol", hue="target", data=data)
# Out:
# <AxesSubplot:xlabel='chol', ylabel='count'>

# %% [markdown]
# #### Here We have to show "cp" content on the basis of "target" with plot

# %%
"""Here we are using again groupby Function which help us to find
Complete Blood Count(cp) Problem OR not Complete Blood Count(cp) Problem in Patients by "cp" """ 

data.groupby("cp")["target"].value_counts()
# Out:
# cp  target
# 0   0         375
#     1         122
# 1   1         134
#     0          33
# 2   1         219
#     0          65
# 3   1          51
#     0          26
# Name: target, dtype: int64

# %%
"""Here we have use seaborn as sns for plotting , here we have shown Complete Blood Count(cp) problem
OR not Complete Blood Count(cp) problem in Male AND Female by plot """

sns.countplot(x="cp", hue="target", data=data)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %% [markdown]
# #### Here We have to show "oldpeak" content on the basis of "target" with plot

# %%
"""Here we are using again groupby Function which help us to find
oldpeak Problem OR not oldpeak Problem in Patients by "oldpeak" """ 

data.groupby("oldpeak")["target"].value_counts()
# Out:
# oldpeak  target
# 0.0      1         242
#          0          87
# 0.1      1          12
#          0          11
# 0.2      1          27
#                   ...
# 4.2      0           3
#          1           3
# 4.4      0           4
# 5.6      0           4
# 6.2      0           3
# Name: target, Length: 61, dtype: int64

# %%
"""Here we have use seaborn as sns for plotting AND matplotlib.pyplot as plt for changing the Size of plot ,
here we have shown oldpeak problem
OR not oldpeak problem in Male AND Female by plot """

plt.figure(figsize=(20,7))
sns.countplot(x="oldpeak", hue="target", data=data)
# Out:
# <AxesSubplot:xlabel='oldpeak', ylabel='count'>

# %% [markdown]
# #### These are the the uses of enumerate Means How enumerate Works

# %%
a = ["work", "eat", "sleep"]
ans = enumerate(a)

print(list(ans))
# Out:
# [(0, 'work'), (1, 'eat'), (2, 'sleep')]

# %%
b = "sheikhEbada"
ans = enumerate(b)

print(list(ans))
# Out:
# [(0, 's'), (1, 'h'), (2, 'e'), (3, 'i'), (4, 'k'), (5, 'h'), (6, 'E'), (7, 'b'), (8, 'a'), (9, 'd'), (10, 'a')]

# %%
categorical_values = list(data.columns)

# %%
categorical_values
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
print(list(enumerate(categorical_values,1)))
# Out:
# [(1, 'age'), (2, 'sex'), (3, 'cp'), (4, 'trestbps'), (5, 'chol'), (6, 'fbs'), (7, 'restecg'), (8, 'thalach'), (9, 'exang'), (10, 'oldpeak'), (11, 'slope'), (12, 'ca'), (13, 'thal'), (14, 'target')]

# %%
categorical_values = list(data.columns)

# %% [raw]
# print(list(enumerate(categorical_values,1)))

# %%
print(categorical_values)
# Out:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %% [markdown]
# #### Here We Will Use plt.subplot, sns.barplot for the purpose of plotting and enumerate

# %%
plt.figure(figsize=(30,30))

for i, col in enumerate(categorical_values,1):
    plt.subplot(4,4,i)
    sns.barplot(x=f"{col}",y="target", data=data) # f = "formating string" mean's kai aap f"{variable name here}" variable name pass krwa sakte hain
    plt.ylabel("Possibility of Having Heart Dieses")
    plt.xlabel(f"{col}")

# %% [markdown]
# #### START MACHINE LEARNING FROM HERE
# #### MODEL BUILDING

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# #### Here We are Using Train_Test_Split

# %%
# First way

arr = data.values
x = arr[:,0:-1]
y = arr[:,-1]

testing_size = 0.2
print(y)
# Out:
# [0. 0. 0. ... 0. 1. 0.]

# %%
#Second way

x = data.drop("target", axis=1)
y = data["target"]

print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x , y, test_size=testing_size)

# %%
print(y_test)
# Out:
# 814    1
# 852    0
# 680    1
# 511    0
# 129    1
#       ..
# 542    1
# 568    1
# 53     0
# 134    1
# 586    0
# Name: target, Length: 205, dtype: int64

# %% [markdown]
# #### Here First We Will Know The Accuracy Then Plot The Confusion Matrix By Using Different Models
# #### Our Goal To Achieve 90% to 100% Accuracy

# %% [markdown]
# #### DECISION TREE CLASSIFIER()

# %%
DT = DecisionTreeClassifier()
DT.fit(x_train, y_train)
y_pred = DT.predict(x_test)
acc = accuracy_score(y_test, y_pred)*100
print(f"Decision Tree accuracy score is: {acc}")

sns.set(font_scale=1.5)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True, fmt="g")
plt.show()
# Out:
# Decision Tree accuracy score is: 98.53658536585365

# %% [markdown]
# #### RANDOM FOREST CLASSIFIER()

# %%
RT = RandomForestClassifier()
RT.fit(x_train, y_train)
y_pred = RT.predict(x_test)
acc = accuracy_score(y_test, y_pred)*100
print(f"Random Forest accuracy score is: {acc}")

sns.set(font_scale=1.5)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True, fmt="g")
plt.show()
# Out:
# Random Forest accuracy score is: 100.0

# %% [markdown]
# #### K NEIGHBORS CLASSSIFIER

# %%
KNN =  KNeighborsClassifier()
KNN.fit(x_train, y_train)
y_pred = KNN.predict(x_test)
acc = accuracy_score(y_test, y_pred)*100
print(f"KNeighbors Classifier accuracy score is: {acc}")

sns.set(font_scale=1.5)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True, fmt="g")
plt.show()
# Out:
# KNeighbors Classifier accuracy score is: 76.58536585365854

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
LR =  LogisticRegression()
LR.fit(x_train, y_train)
y_pred = LR.predict(x_test)
acc = accuracy_score(y_test, y_pred)*100
print(f"LOGISTIC REGRESSION accuracy score is: {acc}")

sns.set(font_scale=1.5)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True, fmt="g")
plt.show()
# Out:
# C:\Users\AA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LOGISTIC REGRESSION accuracy score is: 84.8780487804878

# %% [markdown]
# #### GAUSSIAN NB

# %%
GNB = GaussianNB()
GNB.fit(x_train, y_train)
y_pred = GNB.predict(x_test)
acc = accuracy_score(y_test, y_pred)*100
print(f"GAUSSIAN NB accuracy score is: {acc}")

sns.set(font_scale=1.5)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True, fmt="g")
plt.show()
# Out:
# GAUSSIAN NB accuracy score is: 84.8780487804878

# %% [markdown]
# # NOTE: ONLY DECISION TREE CLASSSIFIER AND RANDOM FOREST CLASSIFIER ARE BEST FOR THIS DATASET CAUSE
# #### THESE TWO MODELS ARE GIVING 95% TO 100% ACCURACY FOR THIS DATASET.
# #### KNEIGHBORS CLASSIFIER, GAUSSIAN NB, LOGISTIC REGRESSION THESE THREE MODELS ARE NOT BEST FOR THIS DATASET CAUSE
# #### THESE THREE MODELS ARE GIVING 75% TO 85% ACCURACY FOR THIS DATASET
